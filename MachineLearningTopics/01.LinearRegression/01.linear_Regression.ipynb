# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r'C:\Users\gvinaykumar\OneDrive - DXC Production\Documents\5. DS_ML\6. Machine Learning\MachineLearningTopics\datasets\Salary Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sns.scatterplot(data=df,x='YearsExperience',y='Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
fig,axes=plt.subplots(1,2,figsize=(10,5))
sns.histplot(data=df,x='YearsExperience',kde=True,ax=axes[0])
sns.histplot(data=df,x='Salary',kde=True,ax=axes[1])
plt.show()

# %% [markdown]
# <b>The data was normally distributed so procceding with the scaling techniques</b>

# %%
YearsExp=df['YearsExperience'].values
Salary=df['Salary'].values

# %%
#splitting data into train and test
X_train, x_test, y_train,y_test=train_test_split(YearsExp,Salary,test_size=0.4,random_state=0)

# %%
scaler = StandardScaler()

# %%
df[['scaled_yrexp','scaled_salary']]=scaler.fit_transform(df[['YearsExperience','Salary']])

# %%
df.head()
# Out:
#    YearsExperience   Salary  scaled_yrexp  scaled_salary
# 0              1.1  39343.0     -1.510053      -1.360113
# 1              1.3  46205.0     -1.438373      -1.105527
# 2              1.5  37731.0     -1.366693      -1.419919
# 3              2.0  43525.0     -1.187494      -1.204957
# 4              2.2  39891.0     -1.115814      -1.339781

# %%
model=LinearRegression()
model.fit(df['scaled_yrexp'].values.reshape(-1,1),df['scaled_salary'])
# Out:
# LinearRegression()
